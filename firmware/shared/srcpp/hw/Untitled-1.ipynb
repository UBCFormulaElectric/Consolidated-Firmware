# %%
from chimera_v2 import CRIT
import chimera_v2

c = CRIT()

# %%
spi_led = chimera_v2.SpiDevice(c,"SEVEN_SEG")
c.gpio_write("GPIO_SEVEN_SEG_RCK", False)

# %%
spi_led.transmit(bytes([0xFF]))
spi_led.transmit(bytes([0xFF]))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 spi_led.transmit(bytes([0xFF]))
#       2 spi_led.transmit(bytes([0xFF]))
#
# File c:\Users\amtaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\chimera_v2.py:525, in SpiDevice.transmit(self, data)
#     523 response = self._owner._read()
#     524 assert response.WhichOneof("payload") == "spi_transmit"
# --> 525 assert response.spi_transmit.success
#
# AssertionError:

# %%
c.gpio_write("GPIO_SEVEN_SEG_RCK", True)
c.gpio_write("GPIO_SEVEN_SEG_RCK", False)
